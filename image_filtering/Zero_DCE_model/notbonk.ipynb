# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
import os
os.chdir('drive/MyDrive/image_filtering/Zero_DCE_model/Zero-DCE/Zero-DCE_code')

# %%
# !python lowlight_test.py
# Out:
# data/test_data/noisy images normalized/9.jpg
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# 0.008194684982299805
# data/test_data/noisy images normalized/8.jpg
# 0.0022177696228027344
# data/test_data/noisy images normalized/14.jpg
# 0.0022847652435302734
# data/test_data/noisy images normalized/28.jpg
# 0.002280712127685547
# data/test_data/noisy images normalized/49.jpg
# 0.00702977180480957
# data/test_data/noisy images normalized/48.jpg
# 0.002341032028198242
# data/test_data/noisy images normalized/61.jpg
# 0.0021173954010009766
# data/test_data/noisy images normalized/58.jpg
# 0.002733469009399414
# data/test_data/noisy images normalized/59.jpg
# 0.0021643638610839844
# data/test_data/noisy images normalized/62.jpg
# 0.0018222332000732422
# data/test_data/noisy images normalized/63.jpg
# ...
